# %%
#Question 1
l1 = [1,2,3,4,5,6,7]
sum = 0
for i in l1:
  sum += i
print(sum)
# Out:
# 28

# %%
#Question 2
l2 = [1,2,3,4,5,6,7]
mult = 1
for i in l2:
  mult = mult*i
print(mult)
# Out:
# 5040

# %%
#Question 3
l3 = [5,1,100,79,44,13,78]
l3.sort(reverse=False)
print(l3[0])
# Out:
# 1

# %%
#Question 4
l4 =[5,1,100,79,44,13,78]
l4.sort(reverse=False)
print(l4[-1])
# Out:
# 100

# %%
#Question 5
l5 =[5,1,100,79,44,13,78]
l5.sort(reverse=False)
print(l4[-2])
# Out:
# 79

# %%
#Question 6
l6 =[5,1,100,79,44,13,78]
N = int(input())
l6.sort(reverse=True)
print(l6[0:N])
# Out:
# 2
# [100, 79]

# %%
#Question 7
l7 =[5,1,100,79,44,13,78]
l=[]
for i in l7:
  if i%2==0:
   l.append(i)
print(l)
# Out:
# [100, 44, 78]

# %%
#Question 8
l7 =[5,1,100,79,44,13,78]
ll=[]
for i in l7:
  if i%2!=0:
   ll.append(i)
print(ll)
# Out:
# [5, 1, 79, 13]

# %%
#Question 9
l9 = [[1,2],[],[3,4,5],[]]
l=[]
for i in l9:
  if i!=[]:
    l.append(i)
print(l)
# Out:
# [[1, 2], [3, 4, 5]]

# %%
#Question 10
l10 =[5,1,100,79,44,13,78]
coppy = l10.copy()

# %%
coppy
# Out:
# [5, 1, 100, 79, 44, 13, 78]

# %%
#Question 11
from collections import Counter

l11 =[5,1,100,79,44,13,78,1]
Counter(l11)
# Out:
# Counter({5: 1, 1: 2, 100: 1, 79: 1, 44: 1, 13: 1, 78: 1})
